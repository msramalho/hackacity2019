# %%
import requests, json
from pprint import pprint

# %% [markdown]
# ### List all datasets

# %%
def get_all_datasets():
    url = "https://opendata.urbanplatform.portodigital.pt/api/3/action/package_list";
    r = requests.get(url)
    return r.json()["result"]

# %%
datasets = get_all_datasets()
# print(datasets)

# %% [markdown]
# ### Get Information for custom dataset, by name
# If `url_only` is true, returns location of data, else a tuple of `(dataset-resource, FORMAT, URL)`

# %%
def get_dataset_info(dataset, url_only=True):
    # returns a generator for (dataset-resource, FORMAT, URL) or just the URL
    url = "https://opendata.urbanplatform.portodigital.pt/api/3/action/package_show?id=%s" % dataset
    j = requests.get(url).json()
    if not j["success"]: print(j["error"]); return
    for resource in j['result']['resources']:
        if url_only: yield resource["url"]
        else: yield (resource["name"], resource["format"], resource["url"])

# %%
alojamento = list(get_dataset_info(datasets[1]))[0]
print(alojamento)
print(list(get_dataset_info(datasets[1], False)))
# Out:
# https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/35
# [('Alojamento Local', 'Esri REST', 'https://servsig.cm-porto.pt/arcgis/rest/services/OpenData_APD/OpenData_APD/MapServer/35')]

# %%
# exemplo com vários
list(get_dataset_info("porto-meteorologia"))
# Out:
# ['https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=WeatherObserved',
#  'https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=WeatherForecast']

# %%
# exemplo com csv que dá "Access denied"
list(get_dataset_info("apdg-zonas-de-estacionamento-pago"))
# Out:
# {'message': 'Access denied: User  not authorized to read package d5d1106b-5db6-4434-b1b2-9083d9fb1f49', '__type': 'Authorization Error'}
# []

# %% [markdown]
# ### Get data from url
#  * Set the query params
#  * Specify how to parse result
#  * function to handle request result and return generator of datapoints

# %%
DEFAULT_REQ_PARAMS = {'where': "1=1", 'returnGeometry': 'true','orderByFields': 'objectid ASC', 'outSR': '4326'}

# %%
def remove_useless_from_dict(dic):
    return {k: v for k, v in dic.items() if v and v!=" "}
def parse_features_geojson(x):
    features = x["properties"]
    features["coordinates"] = x["geometry"]["coordinates"]
    return remove_useless_from_dict(features)
def parse_features_json(x): return remove_useless_from_dict(x["attributes"])

# %%
def get_dataset_data(dataset_url, req_params={"f":"json"}, f="geojson", fields="*", offset=0):
    # default format could be json, but this gives x, y and not lat, lon
    params = DEFAULT_REQ_PARAMS; params.update(req_params); params["f"] = f; params["outFields"]=fields;
    params["resultOffset"]=offset
    data = requests.get(dataset_url + "/query", params=params).json()
    get_attributes = parse_features_geojson if f=="geojson" else parse_features_json
    return map(parse_features_geojson, data["features"])

# %%
def get_dataset_data(dataset_url, req_params={"f":"json"}, f="geojson", fields="*"):
    if "fiware" in dataset_url:
        print("API for broker not parsed yet")
        pprint(requests.get(url).json())
    else:
        # default format could be json, but this gives x, y and not lat, lon
        params = DEFAULT_REQ_PARAMS; params.update(req_params); params["f"] = f; params["outFields"]=fields
        data = requests.get(dataset_url + "/query", params=params).json()
        get_attributes = parse_features_geojson if f=="geojson" else parse_features_json
        return map(parse_features_geojson, data["features"])

# %%
url="https://broker.fiware.urbanplatform.portodigital.pt/v2/entities?type=PointOfInterest"
get_dataset_data(url)
# Out:
# API for broker not parsed yet
# [{'accessibility': {'metadata': {}, 'type': 'Text', 'value': None},
#   'accessibility_es': {'metadata': {}, 'type': 'Text', 'value': None},
#   'accessibility_pt': {'metadata': {}, 'type': 'Text', 'value': None},
#   'address': {'metadata': {},
#               'type': 'StructuredValue',
#               'value': {'addressLocality': 'Porto',
#                         'addressRegion': 'RAMALDE',
#                         'postalCode': '4100-321',
#                         'streetAddress': 'Rua Manuel Pinto de Azevedo, 64'}},
#   'category': {'metadata': {}, 'type': 'StructuredValue', 'value': ['123']},
#   'closedOnHoliday': {'metadata': {}, 'type': 'Text', 'value': None},
#   'contactPoint': {'metadata': {},
#                    'type': 'StructuredValue',
#                    'value': {'email': 'joana.lencastre@1000paladares.com.pt',
#                              'faxNumber': '+351226168337',
#                              'telephone': '+351226168335',
#                              'url': None}},
#   'costDescription': {'metadata': {}, 'type': 'Text', 'value': 'Undefined'},
#   'costDescription_es': {'metadata': {},
#                          'type': 'Text',
#                          'value': 'No definido'},
#   'costDescription_pt': {'metadata': {},
#                          'type': 'Text',
#                          'value': 'Não definido'},
#   'dateModified': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2017-02-27T00:00:00.00Z'},
#   'description': {'metadata': {},
#                   'type': 'Text',
#                   'value': 'The store offers to all lovers of good cooking, '
#                            'products such as Douro wines, jams, honey, herbs, '
#                            'olive oil, vinegar, dried fruit, tea, olives, '
#                            'comfit, liqueur and many other products. '
#                            'Everything for those who appreciate good food. The '
#                            'highlight goes to grapes products and chocolates. '
#                            'It also sells kitchenware and barware. In 1000 '
#                            'Paladares You can do training in the kitchen '
#                            'according to the annual schedule, or reserve the '
#                            'space for groups.'},
#   'description_es': {'metadata': {},
#                      'type': 'Text',
#                      'value': 'La tienda pone a disposición de los amantes de '
#                               'la buena cocina productos como los vinos del '
#                               'Duero, mermeladas, miel, hierbas, aceite de '
#                               'oliva, vinagre, frutos secos, té, aceitunas, '
#                               'confitados, licores y muchos otros. Todo para '
#                               'todos los que disfrutan de la buena '
#                               'gastronomía. Se destacan los productos de la '
#                               'uva y los chocolates. También vende utensilios '
#                               'de cocina y bar. La 1000 Paladares, usted puede '
#                               'hacer formación en  cocina de acuerdo con la '
#                               'programación anual, o  reservar el espacio  '
#                               'para grupos.'},
#   'description_pt': {'metadata': {},
#                      'type': 'Text',
#                      'value': 'Coloca à disposição dos apreciadores da boa '
#                               'cozinha produtos como vinhos do Douro, '
#                               'compotas, mel, ervas aromáticas, azeite, '
#                               'vinagre, frutos secos, chá, azeitonas, '
#                               'confitados, azeitonas, licores e muitos outros. '
#                               'De destacar os produtos de uva e os chocolates. '
#                               'Comercializa também utensílios de cozinha e '
#                               'barware. A 1000 Paladares pode fazer formação '
#                               'em cozinha de acordo com o calendário anual, ou '
#                               'reservar o espaço para grupos.'},
#   'id': 'urn:ngsi-ld:PointOfInterest:porto:portalturismo:31:1207',
#   'internetAccess': {'metadata': {}, 'type': 'Text', 'value': None},
#   'internetWireless': {'metadata': {}, 'type': 'Text', 'value': None},
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.6471177, 41.1730777],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'multimedia': {'metadata': {},
#                  'type': 'StructuredValue',
#                  'value': [{'authorID': '1000 Paladares',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '1000 PALADARES',
#                             'title_es': '1000 PALADARES',
#                             'title_pt': '1000 PALADARES',
#                             'url': 'http://recursos.visitporto.travel/pois/1207_1.jpg'},
#                            {'authorID': '1000 Paladares',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '1000 PALADARES',
#                             'title_es': '1000 PALADARES',
#                             'title_pt': '1000 PALADARES',
#                             'url': 'http://recursos.visitporto.travel/pois/1207_2.jpg'},
#                            {'authorID': '1000 Paladares',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '1000 PALADARES',
#                             'title_es': '1000 PALADARES',
#                             'title_pt': '1000 PALADARES',
#                             'url': 'http://recursos.visitporto.travel/pois/1207_3.jpg'},
#                            {'authorID': '1000 Paladares',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '1000 PALADARES',
#                             'title_es': '1000 PALADARES',
#                             'title_pt': '1000 PALADARES',
#                             'url': 'http://recursos.visitporto.travel/pois/1207_4.jpg'},
#                            {'authorID': '1000 Paladares',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '1000 PALADARES',
#                             'title_es': '1000 PALADARES',
#                             'title_pt': '1000 PALADARES',
#                             'url': 'http://recursos.visitporto.travel/pois/1207_5.jpg'},
#                            {'authorID': '1000 Paladares',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '1000 PALADARES',
#                             'title_es': '1000 PALADARES',
#                             'title_pt': '1000 PALADARES',
#                             'url': 'http://recursos.visitporto.travel/pois/1207_6.jpg'}]},
#   'name': {'metadata': {}, 'type': 'Text', 'value': '1000 Paladares'},
#   'name_es': {'metadata': {}, 'type': 'Text', 'value': '1000 Paladares'},
#   'name_pt': {'metadata': {}, 'type': 'Text', 'value': '1000 Paladares'},
#   'openingHoursSpecification': {'metadata': {},
#                                 'type': 'StructuredValue',
#                                 'value': [{'description': 'Mon-Fri 09:00-13:00 '
#                                                           '/ 14:00-18:00 '
#                                                           'Closed: Sun',
#                                            'description_es': 'Lun-Vie '
#                                                              '09:00-13:00 / '
#                                                              '14:00-18:00 '
#                                                              'Cerrado: Dom',
#                                            'description_pt': 'Seg-Sex '
#                                                              '09:00-13:00 / '
#                                                              '14:00-18:00 '
#                                                              'Encerrado: Dom'},
#                                           {'closes': '18:00:00',
#                                            'dayOfWeek': 'http://schema.org/Sunday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '18:00:00',
#                                            'dayOfWeek': 'http://schema.org/Monday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '18:00:00',
#                                            'dayOfWeek': 'http://schema.org/Tuesday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '18:00:00',
#                                            'dayOfWeek': 'http://schema.org/Wednesday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '18:00:00',
#                                            'dayOfWeek': 'http://schema.org/Thursday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '18:00:00',
#                                            'dayOfWeek': 'http://schema.org/Friday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '18:00:00',
#                                            'dayOfWeek': 'http://schema.org/Saturday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '20:00:00',
#                                            'dayOfWeek': 'http://schema.org/Sunday',
#                                            'opens': '15:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '20:00:00',
#                                            'dayOfWeek': 'http://schema.org/Monday',
#                                            'opens': '15:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '20:00:00',
#                                            'dayOfWeek': 'http://schema.org/Tuesday',
#                                            'opens': '15:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '20:00:00',
#                                            'dayOfWeek': 'http://schema.org/Wednesday',
#                                            'opens': '15:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '20:00:00',
#                                            'dayOfWeek': 'http://schema.org/Thursday',
#                                            'opens': '15:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '20:00:00',
#                                            'dayOfWeek': 'http://schema.org/Friday',
#                                            'opens': '15:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '20:00:00',
#                                            'dayOfWeek': 'http://schema.org/Saturday',
#                                            'opens': '15:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '13:00:00',
#                                            'dayOfWeek': 'http://schema.org/Sunday',
#                                            'opens': '09:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '13:00:00',
#                                            'dayOfWeek': 'http://schema.org/Monday',
#                                            'opens': '09:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '13:00:00',
#                                            'dayOfWeek': 'http://schema.org/Tuesday',
#                                            'opens': '09:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '13:00:00',
#                                            'dayOfWeek': 'http://schema.org/Wednesday',
#                                            'opens': '09:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '13:00:00',
#                                            'dayOfWeek': 'http://schema.org/Thursday',
#                                            'opens': '09:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '13:00:00',
#                                            'dayOfWeek': 'http://schema.org/Friday',
#                                            'opens': '09:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '13:00:00',
#                                            'dayOfWeek': 'http://schema.org/Saturday',
#                                            'opens': '09:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'validFrom': '2020-01-01',
#                                            'validThrough': '2020-01-01'}]},
#   'smokingArea': {'metadata': {}, 'type': 'Text', 'value': None},
#   'socialNetwork': {'metadata': {}, 'type': 'Text', 'value': None},
#   'tag': {'metadata': {}, 'type': 'Text', 'value': 'Gourmet'},
#   'tag_es': {'metadata': {}, 'type': 'Text', 'value': 'Gourmet'},
#   'tag_pt': {'metadata': {}, 'type': 'Text', 'value': 'Gourmet'},
#   'target': {'metadata': {}, 'type': 'Text', 'value': None},
#   'target_es': {'metadata': {}, 'type': 'Text', 'value': None},
#   'target_pt': {'metadata': {}, 'type': 'Text', 'value': None},
#   'touristic': {'metadata': {}, 'type': 'Text', 'value': 'False'},
#   'type': 'PointOfInterest',
#   'wifi': {'metadata': {}, 'type': 'Text', 'value': None}},
#  {'accessibility': {'metadata': {}, 'type': 'Text', 'value': None},
#   'accessibility_es': {'metadata': {}, 'type': 'Text', 'value': None},
#   'accessibility_pt': {'metadata': {}, 'type': 'Text', 'value': None},
#   'address': {'metadata': {},
#               'type': 'StructuredValue',
#               'value': {'addressLocality': 'Porto',
#                         'addressRegion': 'UNIÃO DAS FREGUESIAS DE CEDOFEITA, '
#                                          'SANTO ILDEFONSO, SÉ, MIRAGAIA, SÃO '
#                                          'NICOLAU E VITÓRIA',
#                         'postalCode': '4050-520',
#                         'streetAddress': 'Rua do Rosário, 110'}},
#   'category': {'metadata': {}, 'type': 'StructuredValue', 'value': ['347']},
#   'closedOnHoliday': {'metadata': {}, 'type': 'Text', 'value': None},
#   'contactPoint': {'metadata': {},
#                    'type': 'StructuredValue',
#                    'value': {'email': 'ruadorosario110@gmail.com',
#                              'faxNumber': None,
#                              'telephone': '+351 916762139',
#                              'url': 'ruadorosario110.blogspot.com'}},
#   'costDescription': {'metadata': {}, 'type': 'Text', 'value': 'Low cost'},
#   'costDescription_es': {'metadata': {}, 'type': 'Text', 'value': 'Económico'},
#   'costDescription_pt': {'metadata': {}, 'type': 'Text', 'value': 'Económico'},
#   'dateModified': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2014-04-16T00:00:00.00Z'},
#   'description': {'metadata': {},
#                   'type': 'Text',
#                   'value': 'Space with simple lines, a modern and minimalist '
#                            'decor.    Transcending the restaurant concept, we '
#                            'also have a bar and an art gallery.    The white '
#                            'walls intentionally leave the whole emphasis on '
#                            'the exhibited pieces of art, and it often presents '
#                            'activities for children.'},
#   'description_es': {'metadata': {},
#                      'type': 'Text',
#                      'value': 'Espacio de líneas sencillas, con una decoración '
#                               'moderna y minimalista. Trascendiendo el '
#                               'concepto de restaurante, se presenta también '
#                               'como bar y galería de arte. Las paredes '
#                               'pintadas de blanco realzan las obras expuestas. '
#                               'Frecuentemente ofrece actividades para los más '
#                               'jóvenes.'},
#   'description_pt': {'metadata': {},
#                      'type': 'Text',
#                      'value': 'Espaço de linhas simples, com uma decoração '
#                               'moderna e minimalista.  Trancendendo o conceito '
#                               'de restaurante, assume-se também como bar e '
#                               'galeria de arte.  As paredes propositadamente '
#                               'brancas deixam todo o destaque para as obras aí '
#                               'expostas, Frequentemente apresenta atividades '
#                               'para os mais novos.'},
#   'id': 'urn:ngsi-ld:PointOfInterest:porto:portalturismo:11:2464',
#   'internetAccess': {'metadata': {}, 'type': 'Text', 'value': None},
#   'internetWireless': {'metadata': {}, 'type': 'Text', 'value': None},
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.6207602, 41.1492753],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'multimedia': {'metadata': {}, 'type': 'StructuredValue', 'value': []},
#   'name': {'metadata': {},
#            'type': 'Text',
#            'value': '110–Restaurante, Bar e Galeria'},
#   'name_es': {'metadata': {},
#               'type': 'Text',
#               'value': '110–Restaurante, Bar e Galeria'},
#   'name_pt': {'metadata': {},
#               'type': 'Text',
#               'value': '110–Restaurante, Bar e Galeria'},
#   'openingHoursSpecification': {'metadata': {},
#                                 'type': 'StructuredValue',
#                                 'value': [{'description': 'Mon to Wed '
#                                                           '12:00-15:30  Thu '
#                                                           '12:30-15:30 / '
#                                                           '19:30-01:00  Fri '
#                                                           '12:00-15:30 / '
#                                                           '19:30-04:00  Sat  '
#                                                           '19:30-04:00',
#                                            'description_es': 'Lun a Mie '
#                                                              '12:00-15:30  Jue '
#                                                              '12:30-15:30 / '
#                                                              '19:30-01:00  Vie '
#                                                              '12:00-15:30 / '
#                                                              '19:30-04:00  Sab '
#                                                              '19:30-04:00',
#                                            'description_pt': 'Seg a Qua '
#                                                              '12:00-15:30  Qui '
#                                                              '12:30-15:30 / '
#                                                              '19:30-01:00  '
#                                                              'Sex  12:00-15:30 '
#                                                              '/ 19:30-04:00  '
#                                                              'Sab  '
#                                                              '19:30-04:00'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Sunday',
#                                            'opens': '12:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Monday',
#                                            'opens': '12:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Tuesday',
#                                            'opens': '12:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Wednesday',
#                                            'opens': '12:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Thursday',
#                                            'opens': '12:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Friday',
#                                            'opens': '12:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Saturday',
#                                            'opens': '12:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Sunday',
#                                            'opens': '12:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Monday',
#                                            'opens': '12:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Tuesday',
#                                            'opens': '12:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Wednesday',
#                                            'opens': '12:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Thursday',
#                                            'opens': '12:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Friday',
#                                            'opens': '12:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '15:30:00',
#                                            'dayOfWeek': 'http://schema.org/Saturday',
#                                            'opens': '12:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '01:00:00',
#                                            'dayOfWeek': 'http://schema.org/Sunday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '01:00:00',
#                                            'dayOfWeek': 'http://schema.org/Monday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '01:00:00',
#                                            'dayOfWeek': 'http://schema.org/Tuesday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '01:00:00',
#                                            'dayOfWeek': 'http://schema.org/Wednesday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '01:00:00',
#                                            'dayOfWeek': 'http://schema.org/Thursday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '01:00:00',
#                                            'dayOfWeek': 'http://schema.org/Friday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '01:00:00',
#                                            'dayOfWeek': 'http://schema.org/Saturday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '04:00:00',
#                                            'dayOfWeek': 'http://schema.org/Sunday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '04:00:00',
#                                            'dayOfWeek': 'http://schema.org/Monday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '04:00:00',
#                                            'dayOfWeek': 'http://schema.org/Tuesday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '04:00:00',
#                                            'dayOfWeek': 'http://schema.org/Wednesday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '04:00:00',
#                                            'dayOfWeek': 'http://schema.org/Thursday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '04:00:00',
#                                            'dayOfWeek': 'http://schema.org/Friday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '04:00:00',
#                                            'dayOfWeek': 'http://schema.org/Saturday',
#                                            'opens': '19:30:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'}]},
#   'smokingArea': {'metadata': {}, 'type': 'Text', 'value': None},
#   'socialNetwork': {'metadata': {}, 'type': 'Text', 'value': None},
#   'tag': {'metadata': {}, 'type': 'Text', 'value': 'Miguel Bombarda'},
#   'tag_es': {'metadata': {}, 'type': 'Text', 'value': 'Miguel Bombarda'},
#   'tag_pt': {'metadata': {}, 'type': 'Text', 'value': 'Miguel Bombarda'},
#   'target': {'metadata': {},
#              'type': 'StructuredValue',
#              'value': ['Couples',
#                        'Families',
#                        'Young people',
#                        'MICE Organizers',
#                        'Seniors']},
#   'target_es': {'metadata': {},
#                 'type': 'StructuredValue',
#                 'value': ['Parejas',
#                           'Familias',
#                           'Jóvenes',
#                           'Organizadores MICE',
#                           'Séniores']},
#   'target_pt': {'metadata': {},
#                 'type': 'StructuredValue',
#                 'value': ['Casais',
#                           'Famílias',
#                           'Jovens',
#                           'Organizadores MICE',
#                           'Seniores']},
#   'touristic': {'metadata': {}, 'type': 'Text', 'value': None},
#   'type': 'PointOfInterest',
#   'wifi': {'metadata': {}, 'type': 'Text', 'value': None}},
#  {'accessibility': {'metadata': {}, 'type': 'Text', 'value': 'Physical'},
#   'accessibility_es': {'metadata': {}, 'type': 'Text', 'value': 'Física'},
#   'accessibility_pt': {'metadata': {}, 'type': 'Text', 'value': 'Física'},
#   'address': {'metadata': {},
#               'type': 'StructuredValue',
#               'value': {'addressLocality': 'Porto',
#                         'addressRegion': 'UNIÃO DAS FREGUESIAS DE SANTA '
#                                          'MARINHA E SÃO PEDRO DA AFURADA',
#                         'postalCode': '4400-307',
#                         'streetAddress': 'Alameda Serpa Pinto, 44 B'}},
#   'category': {'metadata': {}, 'type': 'StructuredValue', 'value': ['311']},
#   'closedOnHoliday': {'metadata': {}, 'type': 'Text', 'value': 'False'},
#   'contactPoint': {'metadata': {},
#                    'type': 'StructuredValue',
#                    'value': {'email': 'geral@museurealcompanhiavelha.pt',
#                              'faxNumber': None,
#                              'telephone': '+351 222448501',
#                              'url': 'museurealcompanhiavelha.pt'}},
#   'costDescription': {'metadata': {}, 'type': 'Text', 'value': None},
#   'costDescription_es': {'metadata': {}, 'type': 'Text', 'value': None},
#   'costDescription_pt': {'metadata': {}, 'type': 'Text', 'value': None},
#   'dateModified': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2019-02-04T00:00:00.00Z'},
#   'description': {'metadata': {},
#                   'type': 'Text',
#                   'value': 'Museum of the oldest appellation in the world, '
#                            'dedicated to the oldest Appellated and Regulated '
#                            'World Wine Region, has the mission of sharing with '
#                            'the public the precious documentary and artistic '
#                            'heritage, collected and preserved for more than '
#                            '260 years. Establishing itself as an institutional '
#                            'identity, the Museum intends to promote and '
#                            'disseminate the history and culture of Port Wine, '
#                            'for which the Real Companhia Velha played a '
#                            'decisive role between 1756 and 1834.'},
#   'description_es': {'metadata': {},
#                      'type': 'Text',
#                      'value': 'El Museu da Iª Demarcação, dedicado a la más '
#                               'antigua Región vitivinícola Demarcada y '
#                               'Regulada del Mundo, tiene por misión compartir '
#                               'con el gran público el precioso patrimonio '
#                               'documental y artístico, reunido y preservado a '
#                               'lo largo de más de 260 años. Establecida como '
#                               'una identidad institucional, el Museo pretende '
#                               'promover y divulgar la historia y la cultura '
#                               'del Vino de Porto, para la cual la Real '
#                               'Companhia Velha desempeñó un papel determinante '
#                               'entre 1756 y 1834.'},
#   'description_pt': {'metadata': {},
#                      'type': 'Text',
#                      'value': 'O Museu da Iª Demarcação, dedicado à mais '
#                               'antiga Região Vinícola Demarcada e '
#                               'Regulamentada do Mundo tem por missão partilhar '
#                               'com o grande público o precioso espólio '
#                               'documental e artístico, reunido e preservado ao '
#                               'longo de mais de 260 anos. Estabelecendo-se '
#                               'como uma identidade institucional, o Museu '
#                               'pretende promover e divulgar a história e a '
#                               'cultura do Vinho do Porto, para a qual, a Real '
#                               'Companhia Velha desempenhou um papel '
#                               'determinante entre 1756 e 1834.'},
#   'id': 'urn:ngsi-ld:PointOfInterest:porto:portalturismo:3:3752',
#   'internetAccess': {'metadata': {}, 'type': 'Text', 'value': 'True'},
#   'internetWireless': {'metadata': {}, 'type': 'Text', 'value': 'True'},
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.6183464, 41.1363008],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'multimedia': {'metadata': {},
#                  'type': 'StructuredValue',
#                  'value': [{'authorID': 'A Real Companhia Velha - Atividades '
#                                         'Turísticas, Lda',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '17.56 Museu da 1ª Demarcação',
#                             'title_es': '17.56 Museu da 1ª Demarcação',
#                             'title_pt': '17.56 Museu da 1ª Demarcação',
#                             'url': 'http://recursos.visitporto.travel/pois/3752_8.jpg'},
#                            {'authorID': 'A Real Companhia Velha - Atividades '
#                                         'Turísticas, Lda',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '17.56 Museu da 1ª Demarcação',
#                             'title_es': '17.56 Museu da 1ª Demarcação',
#                             'title_pt': '17.56 Museu da 1ª Demarcação',
#                             'url': 'http://recursos.visitporto.travel/pois/3752_7.jpg'},
#                            {'authorID': 'A Real Companhia Velha - Atividades '
#                                         'Turísticas, Lda',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '17.56 Museu da 1ª Demarcação',
#                             'title_es': '17.56 Museu da 1ª Demarcação',
#                             'title_pt': '17.56 Museu da 1ª Demarcação',
#                             'url': 'http://recursos.visitporto.travel/pois/3752_6.jpg'},
#                            {'authorID': 'A Real Companhia Velha - Atividades '
#                                         'Turísticas, Lda',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '17.56 Museu da 1ª Demarcação',
#                             'title_es': '17.56 Museu da 1ª Demarcação',
#                             'title_pt': '17.56 Museu da 1ª Demarcação',
#                             'url': 'http://recursos.visitporto.travel/pois/3752_5.jpg'},
#                            {'authorID': 'A Real Companhia Velha - Atividades '
#                                         'Turísticas, Lda',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '17.56 Museu da 1ª Demarcação',
#                             'title_es': '17.56 Museu da 1ª Demarcação',
#                             'title_pt': '17.56 Museu da 1ª Demarcação',
#                             'url': 'http://recursos.visitporto.travel/pois/3752_4.jpg'},
#                            {'authorID': 'A Real Companhia Velha - Atividades '
#                                         'Turísticas, Lda',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '17.56 Museu da 1ª Demarcação',
#                             'title_es': '17.56 Museu da 1ª Demarcação',
#                             'title_pt': '17.56 Museu da 1ª Demarcação',
#                             'url': 'http://recursos.visitporto.travel/pois/3752_3.jpg'},
#                            {'authorID': 'A Real Companhia Velha - Atividades '
#                                         'Turísticas, Lda',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
#                             'title': '17.56 Museu da 1ª Demarcação',
#                             'title_es': '17.56 Museu da 1ª Demarcação',
#                             'title_pt': '17.56 Museu da 1ª Demarcação',
#                             'url': 'http://recursos.visitporto.travel/pois/3752_2.jpg'},
#                            {'authorID': 'A Real Companhia Velha - Atividades '
#                                         'Turísticas, Lda',
#                             'label': None,
#                             'label_es': None,
#                             'label_pt': None,
#                             'rightsID': 'CC BY-NC-SA - Some Rights Reserved',
#                             'rightsID_es': 'CC BY-NC-SA - Algunos Derechos '
#                                            'Reservados',
#                             'rightsID_pt': 'CC BY-NC-SA - Alguns Direitos '
#                                            'Reservados',
# ...
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.615083694, 41.151596572],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'multimedia': {'metadata': {}, 'type': 'StructuredValue', 'value': []},
#   'name': {'metadata': {},
#            'type': 'Text',
#            'value': 'A3S - Associação para o Empreendedorismo Social e a '
#                     'Sustentabilidade do Terceiro Setor'},
#   'name_es': {'metadata': {},
#               'type': 'Text',
#               'value': 'A3S - Associação para o Empreendedorismo Social e a '
#                        'Sustentabilidade do Terceiro Setor'},
#   'name_pt': {'metadata': {},
#               'type': 'Text',
#               'value': 'A3S - Associação para o Empreendedorismo Social e a '
#                        'Sustentabilidade do Terceiro Setor'},
#   'openingHoursSpecification': {'metadata': {},
#                                 'type': 'StructuredValue',
#                                 'value': [{'description': None,
#                                            'description_es': None,
#                                            'description_pt': None}]},
#   'smokingArea': {'metadata': {}, 'type': 'Text', 'value': None},
#   'socialNetwork': {'metadata': {}, 'type': 'Text', 'value': None},
#   'tag': {'metadata': {}, 'type': 'Text', 'value': None},
#   'tag_es': {'metadata': {}, 'type': 'Text', 'value': None},
#   'tag_pt': {'metadata': {}, 'type': 'Text', 'value': None},
#   'target': {'metadata': {}, 'type': 'Text', 'value': 'Businessmen'},
#   'target_es': {'metadata': {}, 'type': 'Text', 'value': 'Hombres de negocios'},
#   'target_pt': {'metadata': {}, 'type': 'Text', 'value': 'Homens de negócios'},
#   'touristic': {'metadata': {}, 'type': 'Text', 'value': 'False'},
#   'type': 'PointOfInterest',
#   'wifi': {'metadata': {}, 'type': 'Text', 'value': None}},
#  {'accessibility': {'metadata': {}, 'type': 'Text', 'value': None},
#   'accessibility_es': {'metadata': {}, 'type': 'Text', 'value': None},
#   'accessibility_pt': {'metadata': {}, 'type': 'Text', 'value': None},
#   'address': {'metadata': {},
#               'type': 'StructuredValue',
#               'value': {'addressLocality': 'Vila Nova de Gaia',
#                         'addressRegion': 'UNIÃO DAS FREGUESIAS DE SANTA '
#                                          'MARINHA E SÃO PEDRO DA AFURADA',
#                         'postalCode': '4400-082',
#                         'streetAddress': 'Rua da Carvalhosa, 29'}},
#   'category': {'metadata': {}, 'type': 'StructuredValue', 'value': ['275']},
#   'closedOnHoliday': {'metadata': {}, 'type': 'Text', 'value': None},
#   'contactPoint': {'metadata': {},
#                    'type': 'StructuredValue',
#                    'value': {'email': 'info@sograpevinhos.eu',
#                              'faxNumber': '+351 223759732',
#                              'telephone': '+351 223745292',
#                              'url': 'sograpevinhos.eu'}},
#   'costDescription': {'metadata': {}, 'type': 'Text', 'value': None},
#   'costDescription_es': {'metadata': {}, 'type': 'Text', 'value': None},
#   'costDescription_pt': {'metadata': {}, 'type': 'Text', 'value': None},
#   'dateModified': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2013-01-25T00:00:00.00Z'},
#   'description': {'metadata': {},
#                   'type': 'Text',
#                   'value': 'A. A. Ferreira, S.A. is a wine, cognac and '
#                            'aguardiente producer.'},
#   'description_es': {'metadata': {},
#                      'type': 'Text',
#                      'value': 'A. A. Ferreira, S.A. es una empresa productora '
#                               'de vino, coñac y aguardiente.'},
#   'description_pt': {'metadata': {},
#                      'type': 'Text',
#                      'value': 'A A. A. Ferreira, S.A. é uma empresa de '
#                               'produtores de vinhos, cognac, aguardente.'},
#   'id': 'urn:ngsi-ld:PointOfInterest:porto:portalturismo:56:3118',
#   'internetAccess': {'metadata': {}, 'type': 'Text', 'value': None},
#   'internetWireless': {'metadata': {}, 'type': 'Text', 'value': None},
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.3621923, 41.2995],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'multimedia': {'metadata': {}, 'type': 'StructuredValue', 'value': []},
#   'name': {'metadata': {}, 'type': 'Text', 'value': 'A. A. Ferreira, S.A.'},
#   'name_es': {'metadata': {}, 'type': 'Text', 'value': 'A. A. Ferreira, S.A.'},
#   'name_pt': {'metadata': {}, 'type': 'Text', 'value': 'A. A. Ferreira, S.A.'},
#   'openingHoursSpecification': {'metadata': {},
#                                 'type': 'StructuredValue',
#                                 'value': [{'description': None,
#                                            'description_es': None,
#                                            'description_pt': None}]},
#   'smokingArea': {'metadata': {}, 'type': 'Text', 'value': None},
#   'socialNetwork': {'metadata': {}, 'type': 'Text', 'value': None},
#   'tag': {'metadata': {}, 'type': 'Text', 'value': None},
#   'tag_es': {'metadata': {}, 'type': 'Text', 'value': None},
#   'tag_pt': {'metadata': {}, 'type': 'Text', 'value': None},
#   'target': {'metadata': {}, 'type': 'Text', 'value': 'Businessmen'},
#   'target_es': {'metadata': {}, 'type': 'Text', 'value': 'Hombres de negocios'},
#   'target_pt': {'metadata': {}, 'type': 'Text', 'value': 'Homens de negócios'},
#   'touristic': {'metadata': {}, 'type': 'Text', 'value': None},
#   'type': 'PointOfInterest',
#   'wifi': {'metadata': {}, 'type': 'Text', 'value': None}},
#  {'accessibility': {'metadata': {}, 'type': 'Text', 'value': None},
#   'accessibility_es': {'metadata': {}, 'type': 'Text', 'value': None},
#   'accessibility_pt': {'metadata': {}, 'type': 'Text', 'value': None},
#   'address': {'metadata': {},
#               'type': 'StructuredValue',
#               'value': {'addressLocality': 'Porto',
#                         'addressRegion': 'UNIÃO DAS FREGUESIAS DE CEDOFEITA, '
#                                          'SANTO ILDEFONSO, SÉ, MIRAGAIA, SÃO '
#                                          'NICOLAU E VITÓRIA',
#                         'postalCode': '4000-116',
#                         'streetAddress': 'Rua do Bonjardim, 428-sala 21'}},
#   'category': {'metadata': {}, 'type': 'StructuredValue', 'value': ['47']},
#   'closedOnHoliday': {'metadata': {}, 'type': 'Text', 'value': None},
#   'contactPoint': {'metadata': {},
#                    'type': 'StructuredValue',
#                    'value': {'email': 'aarn@sapo.pt',
#                              'faxNumber': '+351 222030513',
#                              'telephone': '+351 222030513',
#                              'url': 'aarn.pt'}},
#   'costDescription': {'metadata': {}, 'type': 'Text', 'value': None},
#   'costDescription_es': {'metadata': {}, 'type': 'Text', 'value': None},
#   'costDescription_pt': {'metadata': {}, 'type': 'Text', 'value': None},
#   'dateModified': {'metadata': {},
#                    'type': 'DateTime',
#                    'value': '2012-06-25T00:00:00.00Z'},
#   'description': {'metadata': {},
#                   'type': 'Text',
#                   'value': 'The AARN´s primary objective is improving the '
#                            'social and work conditions of artisans in the '
#                            'Northern Region. This is achieved by developing '
#                            'initiative and projects, both national and '
#                            'international, to publicize the sector.'},
#   'description_es': {'metadata': {},
#                      'type': 'Text',
#                      'value': 'La AARN tiene por objetivo prioritario la '
#                               'mejora de las condiciones socioprofesionales de '
#                               'los artesanos de la región norte, desarrollando '
#                               'iniciativas y proyectos a nivel nacional e '
#                               'internacional, para la divulgación del sector.'},
#   'description_pt': {'metadata': {},
#                      'type': 'Text',
#                      'value': 'A AARN tem como objetivo prioritário a melhoria '
#                               'das condições socioprofissionais dos artesãos '
#                               'da Região Norte, desenvolvendo iniciativas e '
#                               'projetos, nacionais e internacionais, para '
#                               'divulgação do setor.'},
#   'id': 'urn:ngsi-ld:PointOfInterest:porto:portalturismo:58:2366',
#   'internetAccess': {'metadata': {}, 'type': 'Text', 'value': None},
#   'internetWireless': {'metadata': {}, 'type': 'Text', 'value': None},
#   'location': {'metadata': {},
#                'type': 'geo:json',
#                'value': {'coordinates': [-8.6093817, 41.1500266],
#                          'crs': {'properties': {'name': 'EPSG:4326'},
#                                  'type': 'name'},
#                          'type': 'Point'}},
#   'multimedia': {'metadata': {}, 'type': 'StructuredValue', 'value': []},
#   'name': {'metadata': {},
#            'type': 'Text',
#            'value': 'AARN-Associação de Artesãos da Região Norte'},
#   'name_es': {'metadata': {},
#               'type': 'Text',
#               'value': 'AARN-Associação de Artesãos da Região Norte'},
#   'name_pt': {'metadata': {},
#               'type': 'Text',
#               'value': 'AARN-Associação de Artesãos da Região Norte'},
#   'openingHoursSpecification': {'metadata': {},
#                                 'type': 'StructuredValue',
#                                 'value': [{'description': 'Mon-Fri  '
#                                                           '10:00-12:30/14:00-17:00',
#                                            'description_es': 'Lun-Vie  '
#                                                              '10:00-12:30/14:00-17:00',
#                                            'description_pt': 'Seg-Sex  '
#                                                              '10:00-12:30/14:00-17:00'},
#                                           {'closes': '12:30:00',
#                                            'dayOfWeek': 'http://schema.org/Sunday',
#                                            'opens': '10:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '12:30:00',
#                                            'dayOfWeek': 'http://schema.org/Monday',
#                                            'opens': '10:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '12:30:00',
#                                            'dayOfWeek': 'http://schema.org/Tuesday',
#                                            'opens': '10:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '12:30:00',
#                                            'dayOfWeek': 'http://schema.org/Wednesday',
#                                            'opens': '10:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '12:30:00',
#                                            'dayOfWeek': 'http://schema.org/Thursday',
#                                            'opens': '10:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '12:30:00',
#                                            'dayOfWeek': 'http://schema.org/Friday',
#                                            'opens': '10:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '12:30:00',
#                                            'dayOfWeek': 'http://schema.org/Saturday',
#                                            'opens': '10:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '17:00:00',
#                                            'dayOfWeek': 'http://schema.org/Sunday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '17:00:00',
#                                            'dayOfWeek': 'http://schema.org/Monday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '17:00:00',
#                                            'dayOfWeek': 'http://schema.org/Tuesday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '17:00:00',
#                                            'dayOfWeek': 'http://schema.org/Wednesday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '17:00:00',
#                                            'dayOfWeek': 'http://schema.org/Thursday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '17:00:00',
#                                            'dayOfWeek': 'http://schema.org/Friday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'},
#                                           {'closes': '17:00:00',
#                                            'dayOfWeek': 'http://schema.org/Saturday',
#                                            'opens': '14:00:00',
#                                            'validFrom': '2019-01-01',
#                                            'validThrough': '2019-12-31'}]},
#   'smokingArea': {'metadata': {}, 'type': 'Text', 'value': None},
#   'socialNetwork': {'metadata': {}, 'type': 'Text', 'value': None},
#   'tag': {'metadata': {}, 'type': 'Text', 'value': None},
#   'tag_es': {'metadata': {}, 'type': 'Text', 'value': None},
#   'tag_pt': {'metadata': {}, 'type': 'Text', 'value': None},
#   'target': {'metadata': {}, 'type': 'Text', 'value': 'Businessmen'},
#   'target_es': {'metadata': {}, 'type': 'Text', 'value': 'Hombres de negocios'},
#   'target_pt': {'metadata': {}, 'type': 'Text', 'value': 'Homens de negócios'},
#   'touristic': {'metadata': {}, 'type': 'Text', 'value': None},
#   'type': 'PointOfInterest',
#   'wifi': {'metadata': {}, 'type': 'Text', 'value': None}}]

# %%
alojamentos = list(get_dataset_data(alojamento))
total = list(get_dataset_data_full(alojamento))
print("There are %d alojamentos" % len(alojamentos))
print("After all there were %s alojamentos" % len(total))
# print(alojamentos)
# Out:
# There are 1000 alojamentos
# After all there were 6657 alojamentos

# %%
print(total[5000])
# Out:
# {'objectid': 5001, 'data_levan': -2209161600000, 'cod_topo': 'RALEG1', 'n_pol': '362', 'nome_aloj': 'Plano de Fuga', 'ano_reg': 2018, 'n_reg': '69821/AL', 'qual_tit': 'Comodatario', 'tit_tipo': 'Pessoa singular (empresário em nome individual)', 'pos_1951': 'S', 'morada': 'Rua da Alegria', 'modalidade': 'Estabelecimento de hospedagem', 'n_policia': '362', 'cod_postal': '4000-035', 'data_reg': 1524441600000, 'data_ab': 1525132800000, 'coordinates': [-8.603564962722654, 41.152752988738456]}

# %%
print(len(set(map(lambda x: str(x["coordinates"]), total))))
# Out:
# 6542
