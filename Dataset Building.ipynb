# %% [markdown]
# ## Imports

# %%
from pprint import pprint
from statistics import mean
import os
import gmplot
import pandas as pd

# %%
from dataset_bending import get_all_datasets, get_dataset_info, get_dataset_data, get_dataset_data_full, try_to_display_dataset, display_dataset_polygon, display_dataset_points, get_dataframe_alojamentos

# %% [markdown]
# # Dataset

# %%
df = get_dataframe_alojamentos()
df["nome"] = df['nome'].str.lower()
df.head(10)
# Out:
# {'objectid': 1, 'data_levan': 1488758400000, 'cod_dmpu': '140747', 'cod_topo': 'RCAMO0', 'n_pol': '77', 'nome_aloj': 'Metro Apartment', 'ano_reg': 2016, 'ano_ab': 2016, 'n_reg': '35375/AL', 'tit_expl': None, 'qual_tit': 'Proprietario', 'tit_tipo': 'Pessoa singular (empresário em nome individual)', 'obs': None, 'pos_1951': 'S', 'nud': None, 'morada': 'Rua Rua Camões, 77 1º 1.1', 'desativo': None, 'modalidade': 'Apartamento', 'n_policia': None, 'cod_postal': '4000-144', 'data_reg': 1475193600000, 'data_ab': 1477958400000, 'toponimo': None, 'cod_freg': None, 'cod_sgr': None, 'n_ordem': None, 'cod_gis': None, 'np_codtopo': None, 'coordinates': [-8.610274113044303, 41.1525537929996]}
#    id     data_levan               nome ano_registo         type  \
# 0   1  1488758400000    metro apartment        2016  Apartamento
# 1   2  1488758400000      be happy flat        2016  Apartamento
# 2   3  1488758400000   camões apartment        2016  Apartamento
# 3   4  1488758400000            zarolho        2016  Apartamento
# 4   5  1488758400000  casa carvalheiras        2016      Moradia
# 5   6  1488758400000    e-house asprela        2016      Moradia
# 6   7  1488758400000               cazv        2016  Apartamento
# 7   8  1488758400000           girassol        2016      Moradia
# 8   9  1488758400000        estudio 312        2016  Apartamento
# 9  10  1488758400000         andorinhas        2016  Apartamento
#
#                                              address  freg     n_reg  \
# 0  Rua Rua Camões, 77 1º 1.1, 4000-144 Porto, Por...  None  35375/AL
# 1  Rua Rua Camões, 327 1.º Hab. 1.5, 4000-145 Por...  None  23120/AL
# 2  Rua Rua Camões, 387 2º Dt, 4000-146 Porto, Por...  None  28842/AL
# 3                         None, None Porto, Portugal  None  28643/AL
# 4                     None, 4000-159 Porto, Portugal  None  36668/AL
# 5                     None, 4200-011 Porto, Portugal  None  26065/AL
# 6  Rua Rua Coutinho de Azevedo, 214 R/C, 4000-189...  None  37182/AL
# 7  Rua Rua Coutinho de Azevedo, 259, 4000-190 Por...  None  28382/AL
# 8                     None, 4000-188 Porto, Portugal  None  35922/AL
# 9                     None, 4200-221 Porto, Portugal  None  32219/AL
#
#          lat       lon
# 0  41.152554 -8.610274
# 1  41.154861 -8.610286
# 2  41.155397 -8.610221
# 3  41.157035 -8.610126
# 4  41.154907 -8.605619
# 5  41.176717 -8.610834
# 6  41.158079 -8.596343
# 7  41.158200 -8.596966
# 8  41.158680 -8.597245
# 9  41.163204 -8.602644

# %%
# dfb = pd.read_csv("sample_ramalho.csv")
dfb = pd.read_csv("data-test.csv")
dfb["name"] = dfb['name'].str.lower()
dfb = dfb.drop_duplicates()
dfb = dfb.drop_duplicates(subset='license', keep='first')
print(len(dfb))
dfb.head(5)
# Out:
# 865
#                                              address   license  \
# 0  250 Rua de Gonçalo Cristóvão 3º Trás, União de...  53360/AL
# 1  Rua do Paraíso 126 2 DT, União de Freguesias d...  32765/AL
# 2  Rua Dr. Alves da Veiga, 205, r/c esq frente, U...  48370/AL
# 3  Rua de Fernandes Tomás 664, 4ºDRT, União de Fr...  80366/AL
# 4  Rua Júlio Dinis 560 5º E, Lordelo do Ouro e Ma...  69414/AL
#
#                                   name  score_cleanliness score_commodities  \
# 0           charming flat @ trindade i                9.7               9,2
# 1                         casa paraíso                9.6               9,5
# 2  sunday - lovely mezzanine in oporto                9.4               9,1
# 3              ana d'ouro apartment ii                9.8               9,1
# 4                         av apartment                9.5               9,4
#
#    score_confort  score_free-wifi  score_global  score_location  \
# 0            9.4             10.0           9.3             9.0
# 1            9.3             10.0           9.5             9.2
# 2            8.9             10.0           9.2             9.2
# 3            9.3             10.0           9.6             9.9
# 4            9.5              NaN           9.4             9.1
#
#    score_price/quality  score_staff          type
# 0                  8.6          9.6  apartamento
# 1                  9.5         10.0  apartamento
# 2                  9.1          9.4  apartamento
# 3                  9.4          9.7  apartamento
# 4                  9.4          9.5  apartamento

# %%
# df.loc[df.apply(lambda row: row[].astype(str).str.contains("(?i)" + "48370").any(), axis=1)]
df[df['n_reg'].str.contains("(?i)" + "48370/AL")==True]
# Out:
#         id      data_levan                 nome ano_registo         type  \
# 3558  3559  -2209161600000  warehouse apartment        2017  Apartamento
#
#                                                 address  freg     n_reg  \
# 3558  Rua do Dr. Alves da Veiga, 4000-074 Porto, Por...  None  48370/AL
#
#           lat       lon
# 3558  41.1505 -8.603682

# %%
# df.join(dfb, lsuffix="name", rsuffix="nome", how="inner")

# %%
df_complete = pd.merge(df, dfb, how="inner", left_on=["nome"], right_on=["name"], suffixes=('', '_y'))
print(len(df_complete)/len(dfb))
# Out:
# 0.4982658959537572

# %%
df_complete = pd.merge(df, dfb, how="inner", left_on=["n_reg"], right_on=["license"], suffixes=('', '_y'))
print(len(df_complete)/len(dfb))
print(len(df_complete)/len(df))
# Out:
# 0.7271676300578035
# 0.09448700615893045

# %%
print(len(dfb))
print(len(df.n_reg))
print(len(df.n_reg.unique()))
print(len(df_complete.license))
print(len(df_complete.drop_duplicates(subset='license', keep='first')))
print(len(df_complete.license.unique()))
# Out:
# 865
# 6657
# 6647
# 629
# 623
# 623

# %% [markdown]
# # TODO complete dataset with info from other sources

# %%
df_complete.columns
# Out:
# Index(['id', 'data_levan', 'nome', 'ano_registo', 'type', 'address', 'freg',
#        'n_reg', 'lat', 'lon', 'address_y', 'license', 'name',
#        'score_cleanliness', 'score_commodities', 'score_confort',
#        'score_free-wifi', 'score_global', 'score_location',
#        'score_price/quality', 'score_staff', 'type_y'],
#       dtype='object')

# %%
df_final = df_complete[["id", "nome", "ano_registo", "type", "n_reg", "lat", "lon", "score_global", "score_location", "score_price/quality"]]
df_complete.head(5)
# Out:
#    id     data_levan                        nome ano_registo  \
# 0   3  1488758400000            camões apartment        2016
# 1  36  1488758400000  alojamento ferreira borges        2016
# 2  47  1488758400000             brigitte aurran        2013
# 3  63  1488758400000         my home in porto ii        2016
# 4  78  1488758400000      residencial d.duarte i        2011
#
#                             type  \
# 0                    Apartamento
# 1                    Apartamento
# 2                        Moradia
# 3                    Apartamento
# 4  Estabelecimento de hospedagem
#
#                                              address  freg     n_reg  \
# 0  Rua Rua Camões, 387 2º Dt, 4000-146 Porto, Por...  None  28842/AL
# 1  Rua Rua Ferreira Borges, 4050-252 Porto, Portugal  None  35755/AL
# 2               Rua Almada, 4050-039 Porto, Portugal  None   5406/AL
# 3  Rua Rua Chaimite, 10 2.º Esquerdo, 4050-193 Po...  None  37939/AL
# 4  Avenida Rodrigues de Freitas, 89, 4000-420 Por...  None  12275/AL
#
#          lat       lon  ...  \
# 0  41.155397 -8.610221  ...
# 1  41.142301 -8.615038  ...
# 2  41.152017 -8.612235  ...
# 3  41.162902 -8.623336  ...
# 4  41.145786 -8.597590  ...
#
#                                                 name score_cleanliness  \
# 0                                   apartment camões               9.6
# 1  adorable apartments in great area by porto cit...               7.7
# 2                                       canto de luz               NaN
# 3                                 my home in porto 2               9.6
# 4                                        d. duarte i               7.3
#
#   score_commodities  score_confort score_free-wifi  score_global  \
# 0               9,3            8.9             9.5           9.4
# 1               7,3            6.9             6.7           7.9
# 2               NaN            NaN             NaN           NaN
# 3               9,2            9.0            10.0           9.2
# 4               6,7            6.7             7.3           7.4
#
#    score_location  score_price/quality  score_staff  \
# 0             9.1                  9.6          9.8
# 1             9.6                  7.3          8.5
# 2             NaN                  NaN          NaN
# 3             8.3                  9.0          9.6
# 4             8.0                  7.7          8.0
#
#                                        type_y
# 0                                apartamento
# 1                                apartamento
# 2  alojamento de acomodação e pequeno-almoço
# 3                                apartamento
# 4                           casa de hóspedes
#
# [5 rows x 22 columns]

# %%
df_final.to_csv("final_dataset.csv", index=None)
